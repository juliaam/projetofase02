# %%
#-----------------------------------------------------------------------------------------------------
# LOGICA E PROGRAMACAO DE COMPUTADORES
# AULA 06 - PARTE 4
# Professora: Silvia Moraes
# Exemplo 2 : Divisores dos 100 primeiros naturais 
# ----------------------------------------------------------------------------------------------------

for num in range(1,101):
  print(">>Numero: ", num)
  d=1
  while d<=num:
    if num %d ==0 : print(d, " divide ", num)
    d = d + 1
# Out:
# >>Numero:  1
# 1  divide  1
# >>Numero:  2
# 1  divide  2
# 2  divide  2
# >>Numero:  3
# 1  divide  3
# 3  divide  3
# >>Numero:  4
# 1  divide  4
# 2  divide  4
# 4  divide  4
# >>Numero:  5
# 1  divide  5
# 5  divide  5
# >>Numero:  6
# 1  divide  6
# 2  divide  6
# 3  divide  6
# 6  divide  6
# >>Numero:  7
# 1  divide  7
# 7  divide  7
# >>Numero:  8
# 1  divide  8
# 2  divide  8
# 4  divide  8
# 8  divide  8
# >>Numero:  9
# 1  divide  9
# 3  divide  9
# 9  divide  9
# >>Numero:  10
# 1  divide  10
# 2  divide  10
# 5  divide  10
# 10  divide  10
# >>Numero:  11
# 1  divide  11
# 11  divide  11
# >>Numero:  12
# 1  divide  12
# 2  divide  12
# 3  divide  12
# 4  divide  12
# 6  divide  12
# 12  divide  12
# >>Numero:  13
# 1  divide  13
# 13  divide  13
# >>Numero:  14
# 1  divide  14
# 2  divide  14
# 7  divide  14
# 14  divide  14
# >>Numero:  15
# 1  divide  15
# 3  divide  15
# 5  divide  15
# 15  divide  15
# >>Numero:  16
# 1  divide  16
# 2  divide  16
# 4  divide  16
# ...
